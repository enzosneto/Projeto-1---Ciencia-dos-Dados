# %% [markdown]
# # Projeto 1 - Enzo Cardoso de Almeida Santos Neto
#
# pergunta: Após a entrada na união europeia, houve aumento na exportação da hungria e da estonia?
#
# Hipótese: Com a entrada na união europeia, ambos os paises, Estonia e Hungria tiveram um aumento na sua porcentagem de exportação em relação ao PIB.

# %%
# %matplotlib inline
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

import os
print('Esperamos trabalhar no diretório')
print(os.getcwd())

dados = pd.read_excel('exports_percent_of_gdp.xlsx')
# Out:
# Esperamos trabalhar no diretório
# C:\Users\enzos\Desktop\Projeto-CD

# %%
index=dados.set_index("country")
lista_paises=["Estonia","Hungary"]
index.loc[:, "Est_Hun"]=0
index.loc[lista_paises, "Est_Hun"]=1
dados_Est_Hun=index.loc[lista_paises]
dados_Est_Hun

transpor=index.transpose()
transpor_quant=transpor[:-1]
ue_anos=transpor_quant.loc[(transpor_quant.index>1999) & (transpor_quant.index<2009),:].transpose()

lista_ue=["Austria","Belgium","Bulgaria","Croatia","Cyprus","Czechia","Denmark","Estonia","Finland","France","Germany","Greece","Hungary","Ireland","Italy","Latvia","Lithuania","Luxembourg","Malta","Netherlands","Poland","Portugal","Romania","Slovakia","Slovenia","Spain","Sweden","United Kingdom"]
dados_uniao_europeia=ue_anos.loc[lista_ue]
dados_uniao_europeia
# Out:
# E:\ANACONDA\lib\site-packages\ipykernel_launcher.py:13: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   del sys.path[0]
#                  2000   2001   2002   2003   2004   2005   2006   2007   2008
# country
# Austria          43.3   44.6   45.3   44.6   46.9   48.6   50.8   52.6   53.2
# Belgium          71.9   71.0   70.3   68.6   70.4   73.5   75.7   77.5   79.7
# Bulgaria         36.5   35.1   33.9   34.7   41.3   42.9   47.3   52.4   52.5
# Croatia          36.5   38.7   37.7   38.9   39.5   39.3   39.7   39.0   38.5
# Cyprus           70.0   68.2   62.4   57.8   56.9   55.7   53.4   53.3   50.1
# Czechia           NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN    NaN
# ...
